# %%
import matplotlib.pyplot as plt
from astropy.io import fits
import os

dir = "E:\\__ONGOING\\Projects\\Krittika Radio\\Week 1\\fits files"

# %%
for filename in os.listdir(dir):
    hdul = fits.open(dir + "\\"+ filename)    
    data = hdul[0].data
    print(filename) 
    print(data.shape)
    if len(data.shape)==4:
        data = data[0][0]
    plt.imshow(data)
    plt.show()
# Out:
# 1-NVSS__J023741.80+015831.1_octet-stream_s2.0arcmin_.fits
# (1, 1, 114, 114)
# 1-VLASS__1.1.ql.T11t04.J023741.80+015831.1.10.2048.v2.I.iter1.image.pbcor.tt0.subim_s2.0arcmin__img-5.fits
# (1, 1, 92, 241)
# 1-VLASS__1.1.ql.T11t04.J023741.80+015831.1.10.2048.v2.I.iter1.image.pbcor.tt0.subim_s2.0arcmin__img-6.fits
# (1, 1, 241, 241)
# 1-VLASS__2.1.ql.T11t04.J023741.80+015831.1.10.2048.v1.I.iter1.image.pbcor.tt0.subim_s2.0arcmin_.fits
# (1, 1, 241, 241)
# 1-VLASS__2.1.ql.T11t04.J023741.80+015831.1.10.2048.v1.I.iter1.image.pbcor.tt0.subim_s2.0arcmin__img-2.fits
# (1, 1, 92, 241)
# 1-VLASS__3.1.ql.T11t04.J023741.80+015831.1.10.2048.v1.I.iter1.image.pbcor.tt0.subim_s2.0arcmin__img-3.fits
# (1, 1, 241, 241)
# 1-VLASS__3.1.ql.T11t04.J023741.80+015831.1.10.2048.v1.I.iter1.image.pbcor.tt0.subim_s2.0arcmin__img-4.fits
# (1, 1, 92, 241)
# 1-WISE__J023741.80+015831.1_0393p015_ac51-w1-int-3_s2.0arcmin_w1.fits
# (175, 175)
